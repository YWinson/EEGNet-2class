# %% [markdown]
# <a href="https://colab.research.google.com/github/amrzhd/EEGNet/blob/main/EEGNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Motor Imagery Task Classification

# %% [markdown]
# #Extracting Data

# %% [markdown]
# ##Downloading BCI Competition IV 2a Dataset

# %%
#!wget https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip

# %%
#!mkdir -p data/cleaned_data/

# %%
# %%capture
#!unzip /content/BCICIV_2a_gdf.zip -d raw_data

# %% [markdown]
# #Installing Packages

# %%
# %%capture
#!pip install mne

# %%
# %%capture
#!pip install torch-summary

# %% [markdown]
# #Libraries Used

# %%
import os
import mne
import math
import copy
import gdown
import random
import scipy.io
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# Torch
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchsummary import summary
from torch.autograd import Variable
from torch.utils.data import DataLoader, TensorDataset, random_split

# Scikit-Learn
from sklearn.feature_selection import mutual_info_classif
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Building Dataset

# %%
# !mkdir -p content/cleaned_data/first_session
# !mkdir -p content/cleaned_data/second_session
# Out:
# �����﷨����ȷ��
# �����﷨����ȷ��

# %% [markdown]
# ##First Session

# %%
# =============================================================================

# First Session 预处理 —— 7 步增强预处理流程

# 参考架构: Notch(50Hz)→Bandpass(4-40Hz)→ICA去伪迹→CAR重参考→Bandpass(8-30Hz)→Epoching+Baseline→逐试次Z-score

# =============================================================================

raw_data_folder = 'D:/Python Program/EEGNet-main/content/raw_data'

cleaned_data_folder = 'D:/Python Program/EEGNet-main/content/cleaned_data/first_session'

# 仅处理单个被试以加速预处理

filtered_files = ['A01T.gdf']

raw_list = []

for file in filtered_files:

    file_path = os.path.join(raw_data_folder, file)

    # 步骤 1: 读取原始 GDF，保留并标记 EOG 通道供 ICA 使用

    raw = mne.io.read_raw_gdf(file_path,

                              eog=['EOG-left', 'EOG-central', 'EOG-right'],

                              preload=True)

    # 步骤 2: 50 Hz 陷波 —— 去除工频干扰

    raw.notch_filter(freqs=50, picks='eeg')

    # 步骤 3: 4-40 Hz 宽带通 —— 保留足够频带供 ICA 识别伪迹

    raw.filter(l_freq=4, h_freq=40, picks='eeg')

    # 步骤 4: ICA 去伪迹 —— 自动识别并剔除眼电/肌电成分

    ica = mne.preprocessing.ICA(n_components=15, random_state=42, method='infomax',

                                 fit_params=dict(extended=True))

    ica.fit(raw, picks='eeg')

    eog_indices, eog_scores = ica.find_bads_eog(raw,

                                                 ch_name=['EOG-left', 'EOG-central', 'EOG-right'],

                                                 threshold=2.5)

    ica.exclude = eog_indices

    print(f'  被试 {file}: 识别到 {len(eog_indices)} 个眼电 ICA 成分')

    raw = ica.apply(raw)

    # 步骤 5: 丢弃 EOG 通道

    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # 步骤 6: CAR 重参考

    raw.set_eeg_reference('average', projection=False)

    # 步骤 7: 二次带通 8-30 Hz（μ节律 + β节律）

    raw.filter(l_freq=8, h_freq=30, picks='eeg')

    # 步骤 8: 保存为 .fif

    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')

    raw.save(new_file_path, overwrite=True)

    raw_list.append(raw)

# 合并所有被试

final_raw = mne.concatenate_raws(raw_list)

new_file_path = os.path.join(cleaned_data_folder, 'First_Session_Subjects.fif')

final_raw.save(new_file_path, overwrite=True)

print(f'First Session 预处理完成: {len(filtered_files)} 个被试文件')

print(f'合并文件保存至: {new_file_path}')
# Out:
# Extracting GDF parameters from D:/Python Program/EEGNet-main/content/raw_data\A01T.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 672527  =      0.000 ...  2690.108 secs...
# c:\Users\Winson\anaconda3\envs\mne\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Computing Extended Infomax ICA
# Fitting ICA took 85.2s.
# Using EOG channels: EOG-left, EOG-central, EOG-right
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
#   被试 A01T.gdf: 识别到 2 个眼电 ICA 成分
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 2 ICA components
#     Projecting back using 22 PCA components
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing D:\Python Program\EEGNet-main\content\cleaned_data\first_session\A01T.fif
# Overwriting existing file.
# C:\Users\Winson\AppData\Local\Temp\ipykernel_36652\1706920428.py:75: RuntimeWarning: This filename (D:\Python Program\EEGNet-main\content\cleaned_data\first_session\A01T.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# Closing D:\Python Program\EEGNet-main\content\cleaned_data\first_session\A01T.fif
# [done]
# Overwriting existing file.
# Writing D:\Python Program\EEGNet-main\content\cleaned_data\first_session\First_Session_Subjects.fif
# Overwriting existing file.
# C:\Users\Winson\AppData\Local\Temp\ipykernel_36652\1706920428.py:85: RuntimeWarning: This filename (D:\Python Program\EEGNet-main\content\cleaned_data\first_session\First_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing D:\Python Program\EEGNet-main\content\cleaned_data\first_session\First_Session_Subjects.fif
# [done]
# First Session 预处理完成: 1 个被试文件
# 合并文件保存至: D:/Python Program/EEGNet-main/content/cleaned_data/first_session\First_Session_Subjects.fif

# %% [markdown]
# 事件列表​
# '1023': 1 拒绝的试验
# '1072': 2 眼动
# '276': 3 静息态脑电图（睁眼）
# '277': 4 静息态脑电图（闭眼）
# '32766': 5 新一组开始
# '768': 6 试验开始
# '769': 7 提示开始 左手（类别1）：0
# '770': 8 提示开始 右手（类别2）：1
# '771': 9 提示开始 脚（类别3）：2
# '772': 10 提示开始 舌头（类别4）：3

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('769'), np.str_('770'), np.str_('771'), np.str_('772')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('769'): 7,
#  np.str_('770'): 8,
#  np.str_('771'): 9,
#  np.str_('772'): 10}

# %% [markdown]
# 时间窗选择：​
# [0秒, 4秒] 提示开始后：[2秒, 6秒]

# %%
# =============================================================================
# First Session Epoching —— tmin=0, tmax=4 (1001 时间点，与旧版一致)
# =============================================================================

# event_id=[7,8]: 仅提取左手(769→7)和右手(770→8)两种运动想象事件
# tmin=0, tmax=4: 截取 cue 开始后 0~4s
#                 250Hz × 4s = 1000 采样点 + 1 = 1001
# baseline=None: 不做基线校正（与旧版一致，方便对比预处理效果）
# reject=None: 不拒绝异常试次（与旧版一致）
# preload=True: 立即加载到内存
epochs = mne.Epochs(final_raw, events[0], event_id=[7, 8],
                    tmin=0, tmax=4,
                    baseline=None,
                    reject=None,
                    preload=True)

print(f'First Session: {len(epochs)} 个有效试次 (共 {len(epochs.drop_log)} 个事件)')

first_session_data = epochs.get_data(copy=True)   # (n_trials, 22, 1001)
first_session_labels = epochs.events[:, -1]        # 标签: 7=左手, 8=右手

print(f'数据形状: {first_session_data.shape}')
# Out:
# Not setting metadata
# 144 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 144 events and 1001 original time points ...
# 0 bad epochs dropped
# First Session: 144 个有效试次 (共 603 个事件)
# 数据形状: (144, 22, 1001)

# %%
print("First_session_dataset shape:",first_session_data.shape)
# Out:
# First_session_dataset shape: (144, 22, 1001)

# %% [markdown]
# ##Second Session

# %% [markdown]
# ###Extracting Labels for datas with "E.gdf" prefix

# %%
# Replace this with your actual shareable link
# shareable_link = 'https://drive.google.com/file/d/11Ke2Xta1kv2xu2Mybuu_X51zJYjQ-VFo/view?usp=drive_link'

# Extract file ID from the shareable link
# file_id = shareable_link.split('/d/')[1].split('/view')[0]

# Create the direct download link
# download_url = f'https://drive.google.com/uc?id={file_id}&export=download'

# Specify the output file path
# output_file = 'true_labels.zip'

# Download the file
# gdown.download(download_url, output_file, quiet=False)

# %%
# %%capture
# !unzip /content/true_labels.zip -d second_session_labels

# %% [markdown]
# ###Extracting datas of second session

# %%
# =============================================================================

# Second Session 预处理 —— 7 步增强预处理流程（同 First Session）

# 参考架构: Notch(50Hz)→Bandpass(4-40Hz)→ICA去伪迹→CAR重参考→Bandpass(8-30Hz)→Epoching+Baseline→逐试次Z-score

# =============================================================================

raw_data_folder = 'D:/Python Program/EEGNet-main/content/raw_data'

cleaned_data_folder = 'D:/Python Program/EEGNet-main/content/cleaned_data/second_session/'

mat_folder = 'D:/Python Program/EEGNet-main/content/second_session_labels/'

# 仅处理单个被试以加速预处理

filtered_files = ['A01E.gdf']

raw_list = []

second_session_labels = np.array([])

for file in filtered_files:

    file_path = os.path.join(raw_data_folder, file)

    # 步骤 1: 读取原始 GDF，保留并标记 EOG 通道供 ICA 使用

    raw = mne.io.read_raw_gdf(file_path,

                              eog=['EOG-left', 'EOG-central', 'EOG-right'],

                              preload=True)

    # 步骤 2: 50 Hz 陷波

    raw.notch_filter(freqs=50, picks='eeg')

    # 步骤 3: 4-40 Hz 宽带通（保留足够频带供 ICA 识别伪迹）

    raw.filter(l_freq=4, h_freq=40, picks='eeg')

    # 步骤 4: ICA 去伪迹

    ica = mne.preprocessing.ICA(n_components=15, random_state=42, method='infomax',

                                 fit_params=dict(extended=True))

    ica.fit(raw, picks='eeg')

    eog_indices, eog_scores = ica.find_bads_eog(raw,

                                                 ch_name=['EOG-left', 'EOG-central', 'EOG-right'],

                                                 threshold=2.5)

    ica.exclude = eog_indices

    print(f'  被试 {file}: 识别到 {len(eog_indices)} 个眼电 ICA 成分')

    raw = ica.apply(raw)

    # 步骤 5: 丢弃 EOG 通道

    raw.drop_channels(['EOG-left', 'EOG-central', 'EOG-right'])

    # 步骤 6: CAR 重参考

    raw.set_eeg_reference('average', projection=False)

    # 步骤 7: 二次带通 8-30 Hz（MI 核心频段）

    raw.filter(l_freq=8, h_freq=30, picks='eeg')

    # 步骤 8: 保存 .fif

    new_file_path = os.path.join(cleaned_data_folder, file[:-4] + '.fif')

    raw.save(new_file_path, overwrite=True)

    raw_list.append(raw)

    # 加载对应的 .mat 标签文件

    mat_file_name = file.replace('.gdf', '.mat')

    mat_file_path = os.path.join(mat_folder, mat_file_name)

    print(f'data:{file}, label:{mat_file_name}')

    if os.path.exists(mat_file_path):

        mat_data = scipy.io.loadmat(mat_file_path)

        class_labels = mat_data.get('classlabel', [])

        if class_labels.size > 0:

            class_labels_array = np.array(class_labels, dtype=int).flatten()

            second_session_labels = np.concatenate((second_session_labels, class_labels_array))

        else:

            print(f"Warning: 'classlabel' not found or empty in {mat_file_name}.")

    else:

        print(f'Warning: {mat_file_name} not found.')

# 合并所有被试

final_raw = mne.concatenate_raws(raw_list)

new_file_path = os.path.join(cleaned_data_folder, 'Second_Session_Subjects.fif')

final_raw.save(new_file_path, overwrite=True)

print(f'Second Session 预处理完成: {len(filtered_files)} 个被试文件')
# Out:
# Extracting GDF parameters from D:/Python Program/EEGNet-main/content/raw_data\A01E.gdf...
# Setting channel info structure...
# Could not determine channel type of the following channels, they will be set as EEG:
# EEG-Fz, EEG, EEG, EEG, EEG, EEG, EEG, EEG-C3, EEG, EEG-Cz, EEG, EEG-C4, EEG, EEG, EEG, EEG, EEG, EEG, EEG, EEG-Pz, EEG, EEG
# Creating raw.info structure...
# Reading 0 ... 686999  =      0.000 ...  2747.996 secs...
# c:\Users\Winson\anaconda3\envs\mne\Lib\contextlib.py:144: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 1651 samples (6.604 s)
#
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Fitting ICA to data using 22 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# Computing Extended Infomax ICA
# Fitting ICA took 94.6s.
# Using EOG channels: EOG-left, EOG-central, EOG-right
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 2500 samples (10.000 s)
#
#   被试 A01E.gdf: 识别到 3 个眼电 ICA 成分
# Applying ICA to Raw instance
#     Transforming to ICA space (15 components)
#     Zeroing out 3 ICA components
#     Projecting back using 22 PCA components
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 8 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 8.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 7.00 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 413 samples (1.652 s)
#
# Overwriting existing file.
# Writing D:\Python Program\EEGNet-main\content\cleaned_data\second_session\A01E.fif
# Overwriting existing file.
# Closing D:\Python Program\EEGNet-main\content\cleaned_data\second_session\A01E.fif
# C:\Users\Winson\AppData\Local\Temp\ipykernel_36652\1023224089.py:79: RuntimeWarning: This filename (D:\Python Program\EEGNet-main\content\cleaned_data\second_session\A01E.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(new_file_path, overwrite=True)
# [done]
# data:A01E.gdf, label:A01E.mat
# Overwriting existing file.
# Writing D:\Python Program\EEGNet-main\content\cleaned_data\second_session\Second_Session_Subjects.fif
# Overwriting existing file.
# C:\Users\Winson\AppData\Local\Temp\ipykernel_36652\1023224089.py:117: RuntimeWarning: This filename (D:\Python Program\EEGNet-main\content\cleaned_data\second_session\Second_Session_Subjects.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   final_raw.save(new_file_path, overwrite=True)
# Closing D:\Python Program\EEGNet-main\content\cleaned_data\second_session\Second_Session_Subjects.fif
# [done]
# Second Session 预处理完成: 1 个被试文件

# %% [markdown]
# **List of the events**
# '1023': 1 Rejected trial
# '1072': 2 Eye movements
# '276': 3 Idling EEG (eyes open)
# '277': 4 Idling EEG (eyes closed)
# '32766': 5 Start of a new run
# '768': 6 Start of a trial
# '783': 7 Cue unknown

# %%
events = mne.events_from_annotations(final_raw)
events[1]
# Out:
# Used Annotations descriptions: [np.str_('1023'), np.str_('1072'), np.str_('276'), np.str_('277'), np.str_('32766'), np.str_('768'), np.str_('783')]
# {np.str_('1023'): 1,
#  np.str_('1072'): 2,
#  np.str_('276'): 3,
#  np.str_('277'): 4,
#  np.str_('32766'): 5,
#  np.str_('768'): 6,
#  np.str_('783'): 7}

# %%
# =============================================================================
# Second Session Epoching —— tmin=0, tmax=4 (1001 时间点，与旧版一致)
# =============================================================================

# Second Session 所有试次使用统一的事件 ID=7（cue unknown），真实标签由 .mat 文件提供
# tmin=0, tmax=4: 截取 cue 开始后 0~4s
# baseline=None: 不做基线校正（与旧版一致）
# reject=None: 不拒绝异常试次（与旧版一致）
epochs = mne.Epochs(final_raw, events[0], event_id=7,
                    tmin=0, tmax=4,
                    baseline=None,
                    reject=None,
                    preload=True)

print(f'Second Session: {len(epochs)} 个有效试次 (共 {len(epochs.drop_log)} 个事件)')

second_session_data = epochs.get_data(copy=True)

print(f'数据形状: {second_session_data.shape}')
# Out:
# Not setting metadata
# 288 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 288 events and 1001 original time points ...
# 0 bad epochs dropped
# Second Session: 288 个有效试次 (共 595 个事件)
# 数据形状: (288, 22, 1001)

# %%
print("Second Session Dataset shape:",second_session_data.shape)
# Out:
# Second Session Dataset shape: (288, 22, 1001)

# %%
# =============================================================================
# 过滤 Second Session: 只保留左手(标签1)和右手(标签2)
# =============================================================================
# second_session_labels 原始值: [1, 2, 3, 4] 对应 [左, 右, 脚, 舌头]
# 只保留标签 1(左手) 和 2(右手)，过滤掉 3(脚) 和 4(舌头)
left_right_mask = (second_session_labels == 1) | (second_session_labels == 2)
second_session_data = second_session_data[left_right_mask]
second_session_labels = second_session_labels[left_right_mask]

print(f"过滤后 Second Session 数据形状: {second_session_data.shape}")
print(f"过滤后 Second Session 标签数: {len(second_session_labels)}")
print(f"类别分布: 左手={np.sum(second_session_labels==1)}, 右手={np.sum(second_session_labels==2)}")
# Out:
# 过滤后 Second Session 数据形状: (144, 22, 1001)
# 过滤后 Second Session 标签数: 144
# 类别分布: 左手=72, 右手=72

# %%
# =============================================================================
# 数据结构化：逐试次 Z-score → 合并 → 划分 → 转 Tensor
# =============================================================================

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = nn.CrossEntropyLoss()

# 标签归一化: [7, 8]→[0, 1], [1, 2]→[0, 1]
y_train = first_session_labels - np.min(first_session_labels)
y_test  = second_session_labels - np.min(second_session_labels)

# 逐试次 Z-score（每个试次独立归一化，axis=(1,2) = 通道×时间）
X_first_session  = (first_session_data  - first_session_data.mean(axis=(1,2), keepdims=True)) / first_session_data.std(axis=(1,2), keepdims=True)
X_second_session = (second_session_data - second_session_data.mean(axis=(1,2), keepdims=True)) / second_session_data.std(axis=(1,2), keepdims=True)

# 合并
X = np.concatenate((X_first_session, X_second_session))
y = np.concatenate((y_train, y_test))

# 90% 训练 / 10% 测试（分层抽样）
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# 转 Tensor
X_train = torch.Tensor(X_train).unsqueeze(1).to(device)
X_test  = torch.Tensor(X_test).unsqueeze(1).to(device)
y_train = torch.LongTensor(y_train).to(device)
y_test  = torch.LongTensor(y_test).to(device)

train_dataset = TensorDataset(X_train, y_train)
test_dataset  = TensorDataset(X_test, y_test)

print('Size of X_train:', X_train.size())
print('Size of X_test:',  X_test.size())
print('Size of y_train:', y_train.size())
print('Size of y_test:',  y_test.size())
# Out:
# Size of X_train: torch.Size([259, 1, 22, 1001])
# Size of X_test: torch.Size([29, 1, 22, 1001])
# Size of y_train: torch.Size([259])
# Size of y_test: torch.Size([29])

# %% [markdown]
# #Training Class

# %%
# =============================================================================
# TrainModel 类 -- 封装模型训练全流程
# =============================================================================
class TrainModel():
    """
    EEGNet 模型训练器

    职责:
        1. 配置优化器 (Adam) 和损失函数 (CrossEntropyLoss)
        2. 执行标准 PyTorch 训练循环 (前向 -> 损失 -> 反向 -> 更新)
        3. 每 epoch 输出训练损失和准确率
        4. 训练完成后保存模型权重
    """

    def __init__(self):
        """
        初始化训练器

        设备选择 (GPU/CPU):
            - 优先使用 NVIDIA GPU (CUDA) 加速矩阵运算
            - 若无 GPU 则回退到 CPU (较慢但可正常运行)
        """
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def train_model(self, model, train_dataset, learning_rate=0.001, batch_size=64, epochs=500):
        """
        执行模型训练

        参数:
            model          : nn.Module -- 待训练的 EEGNet 模型实例
            train_dataset  : TensorDataset -- 训练数据集 (包含 X_train 和 y_train)
            learning_rate  : float -- Adam 优化器的学习率 (默认 0.001)
            batch_size     : int   -- 每批次的样本数 (默认 64)
            epochs         : int   -- 完整遍历训练集的次数 (默认 500)

        返回:
            model : nn.Module -- 训练完成后的模型 (参数已更新至最终状态)

        训练流程 (标准有监督学习):
            对每个 epoch:
                +-- 将模型置为训练模式 (启用 Dropout / BatchNorm 训练行为)
                +-- 遍历 DataLoader 分批加载的 (inputs, labels)
                |   +-- optimizer.zero_grad()              # 清空上轮梯度
                |   +-- outputs = model(inputs)             # 前向传播
                |   +-- loss = criterion(outputs, labels)   # 计算损失
                |   +-- loss.backward()                     # 反向传播 (计算梯度)
                |   +-- optimizer.step()                    # 更新参数 (梯度下降)
                +-- 计算并输出本 epoch 的平均损失和准确率
        """

        # --- 将模型移动到目标设备 (GPU/CPU) ---
        # model.parameters() 和输入数据必须在同一设备上才能计算
        model = model.to(self.device)

        # --- 定义损失函数 ---
        # CrossEntropyLoss = LogSoftmax + NLLLoss
        # 输入:  模型原始输出 logits, 形状 (batch, num_classes) = (batch, 4)
        # 目标:  类别索引, 形状 (batch,), 值为 0/1/2/3
        # 内部自动做 softmax 归一化, 因此模型最后一层不需要加 softmax
        criterion = nn.CrossEntropyLoss()

        # --- 定义优化器 ---
        # Adam (Adaptive Moment Estimation):
        #   - 自适应学习率: 每个参数有独立的自适应学习率
        #   - 结合动量 (Momentum) 和 RMSprop 的优点
        #   - lr=0.001 是 Adam 的常用默认值
        #   - model.parameters() 传入所有可训练参数 (权重和偏置)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)

        # --- 创建数据加载器 ---
        # shuffle=True: 每个 epoch 开始时打乱数据顺序
        #   目的: 防止模型记住样本顺序, 提升泛化能力
        #   原理: 打乱后每个 batch 的样本组成不同, 引入随机性
        # batch_size=64: 每次取 64 个样本一起前向传播
        #   优点: GPU 并行计算, 比逐样本训练快数十倍
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

        # --- 记录训练过程中的最高准确率 ---
        # 用于简单监控; 注意这是训练集准确率而非验证集准确率
        highest_train_accuracy = 0.0

        # =====================================================================
        # 主训练循环
        # =====================================================================
        for epoch in range(epochs):  # 遍历每个 epoch (共 500 轮)

            # --- 设置模型为训练模式 ---
            # 影响以下层的行为:
            #   nn.Dropout(p)   -- 随机丢弃神经元 (训练时启用, 评估时关闭)
            #   nn.BatchNorm2d  -- 使用当前 batch 的统计量更新 running_mean / running_var
            # 注意: 即使不调用 model.train(), Dropout 和 BN 默认也是训练模式,
            #       但显式调用是良好实践, 尤其在训练/评估交替进行时
            model.train()

            # --- 初始化本 epoch 的统计量 ---
            running_loss = 0.0  # 累积损失 (用于计算 epoch 平均损失)
            correct = 0          # 累积预测正确数
            total = 0            # 累积样本总数

            # --- 按 batch 遍历训练数据 ---
            # train_loader 每次 yield (inputs, labels)
            #   inputs 形状: (batch_size, 1, 22, 1001)
            #   labels 形状: (batch_size,)
            for inputs, labels in train_loader:

                # 将数据移动到模型所在设备 (GPU 或 CPU)
                # .to(self.device) 对已在目标设备上的数据是空操作
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                # ============= 核心训练步骤 (五步法) =============

                # 步骤 1: 清空梯度
                # PyTorch 默认会累积梯度 (用于 RNN 等场景),
                # 每次反向传播前必须显式清零, 否则梯度会累加导致参数更新错误
                optimizer.zero_grad()

                # 步骤 2: 前向传播
                # 数据流经 EEGNet 各层:
                #   Block1 (时间卷积) -> Block2 (深度可分离空间卷积 + 池化) ->
                #   Block3 (可分离卷积 + 池化) -> Flatten -> FC
                # 输出 logits, 形状 (batch_size, 4), 每个元素是未归一化的类别得分
                outputs = model(inputs)

                # 步骤 3: 计算损失
                # CrossEntropyLoss 自动将 logits 通过 softmax 转为概率,
                # 然后计算预测概率与真实标签的交叉熵.
                # 损失值越小 -> 模型预测越接近真实标签
                loss = criterion(outputs, labels)

                # 步骤 4: 反向传播
                # 自动计算 loss 对所有 requires_grad=True 的参数的梯度.
                # 梯度存储在 param.grad 中 (如 model.block1[0].weight.grad)
                loss.backward()

                # 步骤 5: 参数更新
                # Adam 优化器根据梯度更新模型参数:
                #   theta_new = theta_old - lr * adam_correction(grad(L))
                # 其中 adam_correction 包含动量项和自适应学习率调整
                optimizer.step()

                # ============= 统计本 batch 的训练指标 =============

                # 累积加权损失
                # loss.item() 从 loss tensor 中提取 Python 标量
                # 乘以 inputs.size(0) (本 batch 样本数) 实现加权:
                #   最后一个 batch 可能不足 batch_size 个样本,
                #   加权后计算 epoch 平均更精确
                running_loss += loss.item() * inputs.size(0)

                # 计算预测类别
                # torch.max(outputs, 1) 返回 (values, indices)
                #   dim=1 表示沿类别维度取最大值
                #   _ 接收最大值 (丢弃), predicted 接收对应索引 (0/1/2/3)
                _, predicted = torch.max(outputs, 1)

                # 累积样本数和正确数
                total += labels.size(0)                                     # 本 batch 样本数
                correct += (predicted == labels).sum().item()               # 预测正确的样本数

            # --- 计算本 epoch 的平均损失和准确率 ---
            # epoch_loss: 所有 batch 的加权平均损失
            #   running_loss 已在累积时按 batch 大小加权
            #   len(train_loader.dataset) = 训练集总样本数 (4665)
            epoch_loss = running_loss / len(train_loader.dataset)

            # epoch_accuracy: 本 epoch 的整体分类准确率
            #   correct / total = 正确样本数 / 总样本数
            #   范围 [0, 1], 如 0.70 表示 70% 准确率
            epoch_accuracy = correct / total

            # --- 更新最高训练准确率记录 ---
            # 注意: 这里追踪的是训练集准确率而非验证集准确率.
            #       训练期间未划分验证集, 因此无法监控过拟合趋势.
            #       参考架构中建议增加验证集以进行早停 (early stopping) [3].
            if epoch_accuracy > highest_train_accuracy:
                highest_train_accuracy = epoch_accuracy

            # --- 输出本 epoch 的训练指标 ---
            # 格式示例: Epoch 127/500, Loss: 0.8734, Accuracy: 64.93%
            print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, "
                  f"Accuracy: {(epoch_accuracy*100):.2f}%")

        # =====================================================================
        # 训练完成后的收尾工作
        # =====================================================================

        # --- 输出最后一轮的平均损失 (与最后一个 epoch_loss 相同, 此处为冗余输出) ---
        average_loss = running_loss / len(train_loader.dataset)
        print("Average Loss:", average_loss)

        # --- 输出训练过程中达到的最高准确率 ---
        # 注意: 由于未划分验证集, 此准确率反映的是模型对训练数据的拟合程度,
        #       而非泛化能力. 需配合后续 test_model() 评估真实的泛化性能.
        print("Highest Train Accuracy:", highest_train_accuracy)

        # --- 保存模型参数 ---
        # torch.save(obj, path) 使用 Python pickle 序列化
        # model.state_dict() 返回有序字典 (OrderedDict), 包含所有层的参数:
        #   例: {'block1.0.weight': tensor(...), 'block1.1.weight': tensor(...), ...}
        # 保存 state_dict (仅参数) 而非整个模型对象的优点:
        #   (1) 文件更小 (不含模型结构代码)
        #   (2) 跨环境兼容 (加载时需先实例化同结构的模型)
        #   (3) PyTorch 推荐做法
        # 注意: 这里保存的是训练结束时的模型状态, 而非 highest_train_accuracy 时的状态
        #       (未实现 best model checkpoint 保存逻辑)
        torch.save(model.state_dict(), 'eegnet_model.pth')

        # 返回训练好的模型, 调用方可直接用于推理或评估
        return model

# %% [markdown]
# #Evaluating Model

# %%
# =============================================================================
# EvalModel 类 -- 封装模型评估全流程
# =============================================================================
class EvalModel():
    """
    EEGNet 模型评估器

    职责:
        1. 在测试集上计算分类准确率
        2. 绘制归一化混淆矩阵 (按真实类别做行归一化)
        3. 可视化并保存混淆矩阵图片
    """

    def __init__(self, model):
        """
        初始化评估器

        参数:
            model : nn.Module -- 已完成训练的模型 (如 TrainModel 返回的模型)

        设备选择:
            - 优先使用 GPU (CUDA), 若无 GPU 则回退到 CPU
            - 模型和测试数据必须位于同一设备上
        """
        # 将模型迁移到目标设备 (GPU/CPU) 并保存引用
        self.model = model.to(device)

        # 记录当前使用的设备 (供后续数据迁移使用)
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    def test_model(self, test_dataset):
        """
        在测试集上评估模型准确率

        参数:
            test_dataset : TensorDataset -- 测试数据集 (包含 X_test 和 y_test)

        返回:
            accuracy : float -- 测试准确率 (百分比, 范围 0~100)

        评估流程:
            对测试集中每个样本逐条前向传播 (batch_size=1),
            统计预测正确的样本数, 计算整体准确率.
            注意: batch_size=1 是为了逐样本评估, 但对 GPU 利用率低,
                  大规模测试时可适当增大 batch_size.
        """

        # --- 设置模型为评估模式 ---
        # 影响以下层的行为:
        #   nn.Dropout(p)   -- 关闭随机丢弃, 所有神经元都参与计算
        #   nn.BatchNorm2d  -- 使用训练阶段累积的 running_mean / running_var,
        #                      而非当前 batch 的统计量
        # 必须调用, 否则模型在测试时会继续使用训练时的随机行为 (Dropout),
        # 导致每次推理结果不一致且准确率偏低
        self.model.eval()

        # --- 初始化统计量 ---
        correct = 0  # 累积预测正确的样本数
        total = 0    # 累积测试样本总数

        # --- 创建测试数据加载器 ---
        # batch_size=1: 逐样本推理
        #   优点: 简单直接, 适合混淆矩阵绘制时收集逐样本预测
        #   缺点: GPU 利用率极低 (每次只算一个样本), 总样本 519 影响不大
        # shuffle=False: 不打乱顺序, 保持原始排列
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        # --- 禁用梯度计算的上下文 ---
        # torch.no_grad() 的作用:
        #   (1) 停止构建计算图 (autograd 不记录操作)
        #   (2) 大幅减少内存占用 (不需要存储中间激活值用于反向传播)
        #   (3) 略微加速推理 (省去梯度追踪开销)
        # 评估阶段必须使用, 否则可能导致 GPU 内存溢出
        with torch.no_grad():
            # 逐样本遍历测试集
            for inputs, labels in test_loader:

                # 将数据迁移到模型所在设备
                inputs = inputs.to(self.device)  # 形状: (1, 1, 22, 1001)
                labels = labels.to(self.device)  # 形状: (1,)

                # 前向传播: 输入 EEG 数据, 输出 logits
                # outputs 形状: (1, 4), 四个元素分别为左/右/脚/舌头的未归一化得分
                outputs = self.model(inputs)

                # 获取预测类别
                # torch.max(outputs.data, 1):
                #   - outputs.data: 取出底层 tensor (与 outputs 等价, .data 是旧写法)
                #   - dim=1: 沿类别维度 (第 1 维) 取最大值
                #   - _: 接收最大值 (不需要)
                #   - predicted: 接收最大值对应的索引 (0/1/2/3)
                _, predicted = torch.max(outputs.data, 1)

                # 累积样本数和正确预测数
                total += labels.size(0)                               # +1 (本样本)
                correct += (predicted == labels).sum().item()         # 若预测正确则 +1

        # --- 计算并输出测试准确率 ---
        # 准确率 = 正确预测样本数 / 总样本数 × 100%
        # 例如: 363 / 519 × 100% ≈ 69.94%
        accuracy = (correct / total) * 100

        # 打印分隔线和结果
        print("/------------------------------/")
        print(f"Test Accuracy: {accuracy:.2f}%")
        print("/------------------------------/")

        return accuracy

    def plot_confusion_matrix(self, test_dataset, classes):
        """
        绘制归一化混淆矩阵

        参数:
            test_dataset : TensorDataset -- 测试数据集
            classes      : list[str]      -- 类别名称列表
                           例: ['Left', 'Right', 'Foot', 'Tongue']

        混淆矩阵说明:
            - 行 (y 轴): 真实标签 (True labels)
            - 列 (x 轴): 预测标签 (Predicted labels)
            - 每个单元格: 该行真实类别的样本中被预测为对应列类别的比例
            - 对角线元素: 各类别的召回率 (Recall), 即正确分类比例
            - 行归一化: 每行元素之和 = 1.00

        输出:
            - 显示热力图
            - 保存为 'confusion_matrix_model.png'
        """

        # --- 设置模型为评估模式 ---
        # 同样必须关闭 Dropout 和冻结 BN 统计量
        self.model.eval()

        # --- 初始化列表, 用于收集所有样本的预测和真实标签 ---
        y_pred = []  # 存储模型对每个样本的预测类别 (整数 0/1/2/3)
        y_true = []  # 存储每个样本的真实类别   (整数 0/1/2/3)

        # 逐样本加载测试集
        test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

        # 禁用梯度计算
        with torch.no_grad():
            for inputs, labels in test_loader:

                # 数据迁移到目标设备
                inputs = inputs.to(self.device)
                labels = labels.to(self.device)

                # 前向传播
                outputs = self.model(inputs)

                # 获取预测类别索引
                _, predicted = torch.max(outputs.data, 1)

                # 记录预测和真实标签
                # predicted.item(): 从单元素 tensor 中提取 Python int
                # labels.item():    同理
                y_pred.append(predicted.item())
                y_true.append(labels.item())

        # --- 构建混淆矩阵 ---
        # confusion_matrix(y_true, y_pred) 返回形状为 (n_classes, n_classes) 的矩阵
        # 矩阵元素 cf_matrix[i, j] = 真实类别为 i 且被预测为 j 的样本数
        cf_matrix = confusion_matrix(y_true, y_pred)

        # --- 行归一化 ---
        # cf_matrix.astype('float'): 转为浮点型 (整数无法做除法)
        # cf_matrix.sum(axis=1): 每行求和, 形状 (n_classes,), 即每个真实类别的总样本数
        # [:, np.newaxis]: 增加一个维度, 形状变为 (n_classes, 1), 用于广播除法
        # 归一化后: 每行元素之和 = 1.00, 对角线元素即为该类别的召回率
        cf_matrix = cf_matrix.astype('float') / cf_matrix.sum(axis=1)[:, np.newaxis]

        # --- 转为 DataFrame 以便绘图 ---
        # index=classes:   行标签 (真实类别名)
        # columns=classes: 列标签 (预测类别名)
        df_cm = pd.DataFrame(cf_matrix, index=classes, columns=classes)

        # --- 使用 seaborn 绘制热力图 ---
        # figsize=(10, 7): 图像尺寸 10×7 英寸
        plt.figure(figsize=(10, 7))

        # sn.heatmap 参数说明:
        #   df_cm:     要绘制的 DataFrame
        #   annot=True: 在每个单元格内显示数值
        #   cmap='Blues': 颜色映射 (白色 -> 深蓝色渐变)
        #   fmt='.2f':  数值显示格式 (保留两位小数)
        sn.heatmap(df_cm, annot=True, cmap='Blues', fmt='.2f')

        # 设置轴标签和标题
        plt.xlabel('Predicted labels')   # x 轴: 模型预测的类别
        plt.ylabel('True labels')        # y 轴: 真实类别
        plt.title('Confusion Matrix')    # 图表标题

        # 保存图片到当前工作目录
        # bbox_inches='tight' (未使用): 可裁剪多余白边, 但此处未传入该参数
        plt.savefig('confusion_matrix_model.png')

        # 显示图片 (在 Jupyter/Colab 中会内联显示)
        plt.show()

# %%
# =============================================================================
# EEGNetModel 类 -- EEGNet-8,2 架构实现 (二分类版, time_points=1001)
# =============================================================================
class EEGNetModel(nn.Module):  # EEGNET-8,2 变体: 8 个时间卷积核, 2 倍深度乘数
    """
    EEGNet: 面向脑电信号的紧凑型卷积神经网络

    论文: "EEGNet: A Compact Convolutional Neural Network for EEG-based
           Brain-Computer Interfaces" (Lawhern et al., 2018)

    架构核心思想:
        1. 时间卷积 (Block1): 学习每个通道上的频域滤波器组
        2. 深度可分离空间卷积 (Block2): 学习通道间的空间模式 (类似 CSP)
        3. 可分离卷积 (Block3): 进一步提取时-空融合特征, 减少参数
        4. 全连接分类头: 将特征映射到类别

    输入形状:  (batch, 1, chans, time_points) = (batch, 1, 22, 1001)
    输出形状:  (batch, classes) = (batch, 2)
    """

    def __init__(self, chans=22, classes=2, time_points=1001, temp_kernel=32,
                 f1=16, f2=32, d=2, pk1=8, pk2=16, dropout_rate=0.5,
                 max_norm1=1, max_norm2=0.25):
        """
        初始化 EEGNet 模型各层

        参数:
            chans        : int -- EEG 通道数 (默认 22, 对应 BCI IV 2a 数据集)
            classes      : int -- 分类类别数 (默认 2: 左/右)
            time_points  : int -- 时间采样点数 (默认 1001, 对应 250Hz × 4s)
            temp_kernel  : int -- 时间卷积核长度 (默认 32, 即 ~128ms @250Hz)
            f1           : int -- 时间卷积输出通道数 (默认 16, 即 16 个频域滤波器)
            f2           : int -- 可分离卷积输出通道数 (默认 32)
            d            : int -- 深度乘数 (默认 2, 每个输入通道生成 d 个空间滤波器)
            pk1          : int -- 第一个池化核大小 (默认 8, 即 8 倍降采样)
            pk2          : int -- 第二个池化核大小 (默认 16, 即 16 倍降采样)
            dropout_rate : float -- Dropout 概率 (默认 0.5, 即随机丢弃 50% 神经元)
            max_norm1    : float -- Block2 深度卷积层的最大范数约束 (默认 1)
            max_norm2    : float -- 全连接层的最大范数约束 (默认 0.25)

        架构命名含义 (EEGNet-8,2):
            - 8: 时间卷积核长度 32 的 1/4 = 8 (原始论文中的 F2 参数)
            - 2: 深度乘数 d=2
        """
        # 调用父类 nn.Module 的构造函数 (注册所有层为子模块)
        super(EEGNetModel, self).__init__()

        # ------------------------------------------------------------------
        # 计算全连接层输入特征数
        # ------------------------------------------------------------------
        # 时间维度经过两次池化后的长度:
        #   第一次池化: time_points // pk1  (1001 // 8  = 125)
        #   第二次池化: (time_points // pk1) // pk2  (125 // 16 = 7)
        #   最终时间维度: time_points // (pk1 * pk2)  (1001 // 128 = 7)
        #
        # 全连接层输入 = 最终时间维度 × f2
        #   本例: 7 × 32 = 224 个特征
        linear_size = (time_points // (pk1 * pk2)) * f2

        # ==================================================================
        # Block 1: 时间卷积层 (Temporal Filters)
        # ==================================================================
        self.block1 = nn.Sequential(
            nn.Conv2d(1, f1, (1, temp_kernel), padding='same', bias=False),
            nn.BatchNorm2d(f1),
        )

        # ==================================================================
        # Block 2: 深度可分离空间卷积 (Spatial Filters)
        # ==================================================================
        self.block2 = nn.Sequential(
            nn.Conv2d(f1, d * f1, (chans, 1), groups=f1, bias=False),  # Depthwise Conv
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1)),
            nn.Dropout(dropout_rate)
        )

        # ==================================================================
        # Block 3: 可分离卷积 (Separable Convolution)
        # ==================================================================
        self.block3 = nn.Sequential(
            nn.Conv2d(d * f1, f2, (1, 16), groups=f2, bias=False, padding='same'),  # Separable Conv
            nn.Conv2d(f2, f2, kernel_size=1, bias=False),                            # Pointwise Conv
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2)),
            nn.Dropout(dropout_rate)
        )

        # ==================================================================
        # 分类头: Flatten + 全连接层
        # ==================================================================
        self.flatten = nn.Flatten()
        self.fc = nn.Linear(linear_size, classes)

        # ==================================================================
        # 应用最大范数约束 (Max-Norm Regularization)
        # ==================================================================
        self._apply_max_norm(self.block2[0], max_norm1)
        self._apply_max_norm(self.fc, max_norm2)

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if 'weight' in name:
                param.data = torch.renorm(param.data, p=2, dim=0, maxnorm=max_norm)

    def forward(self, x):
        x = self.block1(x)   # (batch, 16, 22, 1001)
        x = self.block2(x)   # (batch, 32, 1, 125)
        x = self.block3(x)   # (batch, 32, 1, 7)
        x = self.flatten(x)  # (batch, 224)
        x = self.fc(x)       # (batch, 2)
        return x

# %%
# =============================================================================
# 模型实例化与结构可视化 (二分类, time_points=1001)
# =============================================================================

# 定义模型输入尺寸 (不含 batch 维度)
# 格式: (channels_in, chans_eeg, time_points)
input_size = (1, 22, 1001)

# 实例化 EEGNet 模型并迁移到目标设备 (GPU/CPU)
# 使用默认参数: chans=22, classes=2, time_points=1001
#   temp_kernel=32, f1=16, f2=32, d=2
#   pk1=8, pk2=16, dropout_rate=0.5
#   max_norm1=1, max_norm2=0.25
# .to(device) 将模型参数复制到 GPU (若可用) 或 CPU
eegnet_model = EEGNetModel(classes=2).to(device)

# 使用 torchsummary 打印模型结构摘要
summary(eegnet_model, input_size)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 2]                   450
# ==========================================================================================
# Total params: 3,362
# Trainable params: 3,362
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.05
# ==========================================================================================
# c:\Users\Winson\anaconda3\envs\mne\Lib\site-packages\torch\nn\modules\conv.py:549: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\Convolution.cpp:1037.)
#   return F.conv2d(
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 16, 22, 1001]        --
# |    └─Conv2d: 2-1                       [-1, 16, 22, 1001]        512
# |    └─BatchNorm2d: 2-2                  [-1, 16, 22, 1001]        32
# ├─Sequential: 1-2                        [-1, 32, 1, 125]          --
# |    └─Conv2d: 2-3                       [-1, 32, 1, 1001]         704
# |    └─BatchNorm2d: 2-4                  [-1, 32, 1, 1001]         64
# |    └─ELU: 2-5                          [-1, 32, 1, 1001]         --
# |    └─AvgPool2d: 2-6                    [-1, 32, 1, 125]          --
# |    └─Dropout: 2-7                      [-1, 32, 1, 125]          --
# ├─Sequential: 1-3                        [-1, 32, 1, 7]            --
# |    └─Conv2d: 2-8                       [-1, 32, 1, 125]          512
# |    └─Conv2d: 2-9                       [-1, 32, 1, 125]          1,024
# |    └─BatchNorm2d: 2-10                 [-1, 32, 1, 125]          64
# |    └─ELU: 2-11                         [-1, 32, 1, 125]          --
# |    └─AvgPool2d: 2-12                   [-1, 32, 1, 7]            --
# |    └─Dropout: 2-13                     [-1, 32, 1, 7]            --
# ├─Flatten: 1-4                           [-1, 224]                 --
# ├─Linear: 1-5                            [-1, 2]                   450
# ==========================================================================================
# Total params: 3,362
# Trainable params: 3,362
# Non-trainable params: 0
# Total mult-adds (M): 12.18
# ==========================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 5.96
# Params size (MB): 0.01
# Estimated Total Size (MB): 6.05
# ==========================================================================================

# %%
# =============================================================================
# 模型训练执行 (二分类: 左手 vs 右手, time_points=1001)
# =============================================================================

# 实例化 EEGNet 模型 (二分类) 并迁移到 GPU (或 CPU)
eegnet_model = EEGNetModel(classes=2).to(device)

# =============================================================================
# 训练超参数配置
# =============================================================================
EPOCHS = 500
BATCH_SIZE = 64
LEARNING_RATE = 0.001

# =============================================================================
# 实例化训练器并开始训练
# =============================================================================
trainer = TrainModel()

trained_eegnet_model = trainer.train_model(
    eegnet_model,
    train_dataset,
    learning_rate=LEARNING_RATE,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS
)

# 保存训练好的模型参数
torch.save(trained_eegnet_model.state_dict(), 'eegnet_model.pth')
# Out:
# Epoch 1/500, Loss: 0.6940, Accuracy: 51.35%
# Epoch 2/500, Loss: 0.6910, Accuracy: 53.28%
# Epoch 3/500, Loss: 0.6932, Accuracy: 54.05%
# Epoch 4/500, Loss: 0.6888, Accuracy: 53.28%
# Epoch 5/500, Loss: 0.6930, Accuracy: 49.42%
# Epoch 6/500, Loss: 0.6917, Accuracy: 52.12%
# Epoch 7/500, Loss: 0.6861, Accuracy: 54.44%
# Epoch 8/500, Loss: 0.6778, Accuracy: 60.62%
# Epoch 9/500, Loss: 0.6802, Accuracy: 58.69%
# Epoch 10/500, Loss: 0.6803, Accuracy: 59.46%
# Epoch 11/500, Loss: 0.6683, Accuracy: 70.27%
# Epoch 12/500, Loss: 0.6735, Accuracy: 62.93%
# Epoch 13/500, Loss: 0.6747, Accuracy: 59.85%
# Epoch 14/500, Loss: 0.6575, Accuracy: 69.11%
# Epoch 15/500, Loss: 0.6551, Accuracy: 66.02%
# Epoch 16/500, Loss: 0.6376, Accuracy: 70.27%
# Epoch 17/500, Loss: 0.6291, Accuracy: 65.64%
# Epoch 18/500, Loss: 0.6195, Accuracy: 70.27%
# Epoch 19/500, Loss: 0.5901, Accuracy: 71.81%
# Epoch 20/500, Loss: 0.5694, Accuracy: 79.15%
# Epoch 21/500, Loss: 0.5383, Accuracy: 77.99%
# Epoch 22/500, Loss: 0.5119, Accuracy: 82.63%
# Epoch 23/500, Loss: 0.5031, Accuracy: 79.15%
# Epoch 24/500, Loss: 0.4669, Accuracy: 81.08%
# Epoch 25/500, Loss: 0.4595, Accuracy: 80.69%
# Epoch 26/500, Loss: 0.4484, Accuracy: 79.15%
# Epoch 27/500, Loss: 0.4150, Accuracy: 83.78%
# Epoch 28/500, Loss: 0.4034, Accuracy: 82.24%
# Epoch 29/500, Loss: 0.3904, Accuracy: 86.49%
# Epoch 30/500, Loss: 0.3826, Accuracy: 85.33%
# Epoch 31/500, Loss: 0.3660, Accuracy: 85.71%
# Epoch 32/500, Loss: 0.3582, Accuracy: 83.01%
# Epoch 33/500, Loss: 0.3722, Accuracy: 81.08%
# Epoch 34/500, Loss: 0.3372, Accuracy: 84.17%
# Epoch 35/500, Loss: 0.3665, Accuracy: 84.56%
# Epoch 36/500, Loss: 0.3310, Accuracy: 86.87%
# Epoch 37/500, Loss: 0.3384, Accuracy: 84.56%
# Epoch 38/500, Loss: 0.2997, Accuracy: 88.42%
# Epoch 39/500, Loss: 0.3125, Accuracy: 85.33%
# Epoch 40/500, Loss: 0.3487, Accuracy: 84.17%
# Epoch 41/500, Loss: 0.3229, Accuracy: 86.87%
# Epoch 42/500, Loss: 0.2532, Accuracy: 89.19%
# Epoch 43/500, Loss: 0.2587, Accuracy: 88.80%
# Epoch 44/500, Loss: 0.3100, Accuracy: 88.03%
# Epoch 45/500, Loss: 0.3018, Accuracy: 85.33%
# Epoch 46/500, Loss: 0.2844, Accuracy: 86.49%
# Epoch 47/500, Loss: 0.3049, Accuracy: 85.33%
# Epoch 48/500, Loss: 0.2973, Accuracy: 85.71%
# Epoch 49/500, Loss: 0.2935, Accuracy: 86.49%
# Epoch 50/500, Loss: 0.2767, Accuracy: 86.87%
# Epoch 51/500, Loss: 0.2879, Accuracy: 88.42%
# Epoch 52/500, Loss: 0.2794, Accuracy: 88.80%
# Epoch 53/500, Loss: 0.2755, Accuracy: 89.58%
# Epoch 54/500, Loss: 0.2546, Accuracy: 88.42%
# Epoch 55/500, Loss: 0.3192, Accuracy: 84.56%
# Epoch 56/500, Loss: 0.2974, Accuracy: 87.64%
# Epoch 57/500, Loss: 0.2542, Accuracy: 89.19%
# Epoch 58/500, Loss: 0.2407, Accuracy: 89.19%
# Epoch 59/500, Loss: 0.2412, Accuracy: 91.89%
# Epoch 60/500, Loss: 0.2830, Accuracy: 86.10%
# Epoch 61/500, Loss: 0.2788, Accuracy: 86.87%
# Epoch 62/500, Loss: 0.2588, Accuracy: 89.96%
# Epoch 63/500, Loss: 0.2367, Accuracy: 89.96%
# Epoch 64/500, Loss: 0.2591, Accuracy: 88.03%
# Epoch 65/500, Loss: 0.2497, Accuracy: 90.73%
# Epoch 66/500, Loss: 0.2660, Accuracy: 86.87%
# Epoch 67/500, Loss: 0.2455, Accuracy: 89.58%
# Epoch 68/500, Loss: 0.2432, Accuracy: 88.80%
# Epoch 69/500, Loss: 0.2378, Accuracy: 91.51%
# Epoch 70/500, Loss: 0.2536, Accuracy: 91.12%
# Epoch 71/500, Loss: 0.2371, Accuracy: 89.58%
# Epoch 72/500, Loss: 0.2467, Accuracy: 88.80%
# Epoch 73/500, Loss: 0.2414, Accuracy: 90.73%
# Epoch 74/500, Loss: 0.2337, Accuracy: 89.96%
# Epoch 75/500, Loss: 0.2553, Accuracy: 89.96%
# Epoch 76/500, Loss: 0.2224, Accuracy: 89.96%
# Epoch 77/500, Loss: 0.1930, Accuracy: 93.82%
# Epoch 78/500, Loss: 0.2415, Accuracy: 88.42%
# Epoch 79/500, Loss: 0.2578, Accuracy: 88.80%
# Epoch 80/500, Loss: 0.2100, Accuracy: 91.89%
# Epoch 81/500, Loss: 0.2288, Accuracy: 90.35%
# Epoch 82/500, Loss: 0.2225, Accuracy: 90.73%
# Epoch 83/500, Loss: 0.2264, Accuracy: 91.51%
# Epoch 84/500, Loss: 0.2184, Accuracy: 89.58%
# Epoch 85/500, Loss: 0.2422, Accuracy: 90.73%
# Epoch 86/500, Loss: 0.1974, Accuracy: 91.89%
# Epoch 87/500, Loss: 0.1603, Accuracy: 93.82%
# Epoch 88/500, Loss: 0.2018, Accuracy: 92.66%
# Epoch 89/500, Loss: 0.1819, Accuracy: 93.82%
# Epoch 90/500, Loss: 0.2077, Accuracy: 91.51%
# Epoch 91/500, Loss: 0.1851, Accuracy: 93.82%
# Epoch 92/500, Loss: 0.2139, Accuracy: 91.89%
# Epoch 93/500, Loss: 0.1860, Accuracy: 92.66%
# Epoch 94/500, Loss: 0.1880, Accuracy: 93.44%
# Epoch 95/500, Loss: 0.1899, Accuracy: 91.12%
# Epoch 96/500, Loss: 0.2146, Accuracy: 90.35%
# Epoch 97/500, Loss: 0.1953, Accuracy: 91.51%
# Epoch 98/500, Loss: 0.1947, Accuracy: 89.96%
# Epoch 99/500, Loss: 0.1438, Accuracy: 95.37%
# Epoch 100/500, Loss: 0.1734, Accuracy: 92.66%
# Epoch 101/500, Loss: 0.1723, Accuracy: 92.28%
# Epoch 102/500, Loss: 0.1645, Accuracy: 92.28%
# Epoch 103/500, Loss: 0.2161, Accuracy: 90.73%
# Epoch 104/500, Loss: 0.1938, Accuracy: 92.28%
# Epoch 105/500, Loss: 0.1528, Accuracy: 91.51%
# Epoch 106/500, Loss: 0.1808, Accuracy: 93.44%
# Epoch 107/500, Loss: 0.1734, Accuracy: 93.05%
# Epoch 108/500, Loss: 0.1761, Accuracy: 93.44%
# Epoch 109/500, Loss: 0.2018, Accuracy: 90.73%
# Epoch 110/500, Loss: 0.1827, Accuracy: 93.05%
# Epoch 111/500, Loss: 0.1794, Accuracy: 95.37%
# Epoch 112/500, Loss: 0.1598, Accuracy: 94.98%
# Epoch 113/500, Loss: 0.1466, Accuracy: 95.37%
# Epoch 114/500, Loss: 0.1611, Accuracy: 92.66%
# Epoch 115/500, Loss: 0.1481, Accuracy: 93.82%
# Epoch 116/500, Loss: 0.2114, Accuracy: 91.89%
# Epoch 117/500, Loss: 0.1416, Accuracy: 94.21%
# Epoch 118/500, Loss: 0.1339, Accuracy: 95.75%
# Epoch 119/500, Loss: 0.1548, Accuracy: 94.98%
# Epoch 120/500, Loss: 0.1435, Accuracy: 95.37%
# Epoch 121/500, Loss: 0.1328, Accuracy: 94.21%
# Epoch 122/500, Loss: 0.1545, Accuracy: 94.59%
# Epoch 123/500, Loss: 0.1323, Accuracy: 96.14%
# Epoch 124/500, Loss: 0.1230, Accuracy: 95.75%
# Epoch 125/500, Loss: 0.1389, Accuracy: 94.59%
# Epoch 126/500, Loss: 0.1296, Accuracy: 95.37%
# Epoch 127/500, Loss: 0.1175, Accuracy: 96.14%
# Epoch 128/500, Loss: 0.1202, Accuracy: 96.91%
# Epoch 129/500, Loss: 0.1392, Accuracy: 94.59%
# Epoch 130/500, Loss: 0.1254, Accuracy: 94.98%
# Epoch 131/500, Loss: 0.1201, Accuracy: 93.82%
# Epoch 132/500, Loss: 0.1446, Accuracy: 94.21%
# Epoch 133/500, Loss: 0.1569, Accuracy: 92.66%
# Epoch 134/500, Loss: 0.1386, Accuracy: 93.44%
# Epoch 135/500, Loss: 0.1240, Accuracy: 95.37%
# Epoch 136/500, Loss: 0.1278, Accuracy: 95.75%
# Epoch 137/500, Loss: 0.1631, Accuracy: 93.44%
# Epoch 138/500, Loss: 0.1489, Accuracy: 94.59%
# Epoch 139/500, Loss: 0.1042, Accuracy: 95.75%
# Epoch 140/500, Loss: 0.1638, Accuracy: 94.21%
# Epoch 141/500, Loss: 0.1435, Accuracy: 93.44%
# Epoch 142/500, Loss: 0.1261, Accuracy: 96.14%
# Epoch 143/500, Loss: 0.1505, Accuracy: 93.82%
# Epoch 144/500, Loss: 0.1449, Accuracy: 93.82%
# Epoch 145/500, Loss: 0.1264, Accuracy: 94.59%
# Epoch 146/500, Loss: 0.1225, Accuracy: 94.21%
# Epoch 147/500, Loss: 0.1416, Accuracy: 94.59%
# Epoch 148/500, Loss: 0.1180, Accuracy: 95.37%
# Epoch 149/500, Loss: 0.1282, Accuracy: 94.59%
# Epoch 150/500, Loss: 0.1457, Accuracy: 93.82%
# Epoch 151/500, Loss: 0.1659, Accuracy: 94.21%
# Epoch 152/500, Loss: 0.1348, Accuracy: 93.82%
# Epoch 153/500, Loss: 0.1306, Accuracy: 93.44%
# Epoch 154/500, Loss: 0.1380, Accuracy: 93.82%
# Epoch 155/500, Loss: 0.1302, Accuracy: 94.98%
# Epoch 156/500, Loss: 0.1747, Accuracy: 94.21%
# Epoch 157/500, Loss: 0.1332, Accuracy: 94.21%
# Epoch 158/500, Loss: 0.1326, Accuracy: 94.21%
# Epoch 159/500, Loss: 0.1460, Accuracy: 94.59%
# Epoch 160/500, Loss: 0.1478, Accuracy: 92.66%
# Epoch 161/500, Loss: 0.1433, Accuracy: 94.98%
# Epoch 162/500, Loss: 0.1190, Accuracy: 95.75%
# Epoch 163/500, Loss: 0.1044, Accuracy: 95.75%
# Epoch 164/500, Loss: 0.1443, Accuracy: 94.98%
# Epoch 165/500, Loss: 0.1008, Accuracy: 96.53%
# Epoch 166/500, Loss: 0.1196, Accuracy: 94.98%
# Epoch 167/500, Loss: 0.1166, Accuracy: 96.14%
# Epoch 168/500, Loss: 0.1097, Accuracy: 96.14%
# Epoch 169/500, Loss: 0.1569, Accuracy: 93.44%
# Epoch 170/500, Loss: 0.1055, Accuracy: 96.14%
# Epoch 171/500, Loss: 0.1195, Accuracy: 94.98%
# Epoch 172/500, Loss: 0.0944, Accuracy: 96.14%
# Epoch 173/500, Loss: 0.1246, Accuracy: 94.59%
# Epoch 174/500, Loss: 0.1375, Accuracy: 94.59%
# Epoch 175/500, Loss: 0.1210, Accuracy: 96.91%
# Epoch 176/500, Loss: 0.0896, Accuracy: 97.30%
# Epoch 177/500, Loss: 0.1147, Accuracy: 95.37%
# Epoch 178/500, Loss: 0.1271, Accuracy: 95.75%
# Epoch 179/500, Loss: 0.1498, Accuracy: 93.82%
# Epoch 180/500, Loss: 0.1348, Accuracy: 94.21%
# Epoch 181/500, Loss: 0.1271, Accuracy: 94.98%
# Epoch 182/500, Loss: 0.1298, Accuracy: 96.14%
# Epoch 183/500, Loss: 0.1244, Accuracy: 96.53%
# Epoch 184/500, Loss: 0.1465, Accuracy: 94.98%
# Epoch 185/500, Loss: 0.1220, Accuracy: 93.82%
# Epoch 186/500, Loss: 0.1002, Accuracy: 96.14%
# Epoch 187/500, Loss: 0.1135, Accuracy: 95.37%
# Epoch 188/500, Loss: 0.1660, Accuracy: 92.66%
# Epoch 189/500, Loss: 0.1118, Accuracy: 95.75%
# Epoch 190/500, Loss: 0.1044, Accuracy: 96.53%
# Epoch 191/500, Loss: 0.1094, Accuracy: 96.14%
# Epoch 192/500, Loss: 0.1198, Accuracy: 97.30%
# Epoch 193/500, Loss: 0.1137, Accuracy: 94.59%
# Epoch 194/500, Loss: 0.1080, Accuracy: 97.68%
# Epoch 195/500, Loss: 0.0978, Accuracy: 95.75%
# Epoch 196/500, Loss: 0.1099, Accuracy: 96.14%
# Epoch 197/500, Loss: 0.1284, Accuracy: 93.82%
# Epoch 198/500, Loss: 0.1361, Accuracy: 95.37%
# Epoch 199/500, Loss: 0.1099, Accuracy: 96.14%
# Epoch 200/500, Loss: 0.0908, Accuracy: 96.53%
# Epoch 201/500, Loss: 0.0966, Accuracy: 96.91%
# Epoch 202/500, Loss: 0.0970, Accuracy: 96.91%
# Epoch 203/500, Loss: 0.0769, Accuracy: 98.84%
# Epoch 204/500, Loss: 0.0871, Accuracy: 97.30%
# Epoch 205/500, Loss: 0.0891, Accuracy: 97.68%
# Epoch 206/500, Loss: 0.1053, Accuracy: 96.53%
# Epoch 207/500, Loss: 0.1121, Accuracy: 96.14%
# Epoch 208/500, Loss: 0.0935, Accuracy: 97.68%
# Epoch 209/500, Loss: 0.0657, Accuracy: 99.23%
# Epoch 210/500, Loss: 0.1283, Accuracy: 95.37%
# Epoch 211/500, Loss: 0.0872, Accuracy: 96.53%
# Epoch 212/500, Loss: 0.0773, Accuracy: 98.46%
# Epoch 213/500, Loss: 0.0940, Accuracy: 96.53%
# Epoch 214/500, Loss: 0.0995, Accuracy: 97.68%
# Epoch 215/500, Loss: 0.0990, Accuracy: 96.91%
# Epoch 216/500, Loss: 0.0918, Accuracy: 96.53%
# Epoch 217/500, Loss: 0.1107, Accuracy: 96.14%
# Epoch 218/500, Loss: 0.1135, Accuracy: 95.75%
# Epoch 219/500, Loss: 0.0928, Accuracy: 96.91%
# Epoch 220/500, Loss: 0.0743, Accuracy: 97.68%
# Epoch 221/500, Loss: 0.1215, Accuracy: 95.37%
# Epoch 222/500, Loss: 0.0947, Accuracy: 95.37%
# Epoch 223/500, Loss: 0.0926, Accuracy: 96.91%
# Epoch 224/500, Loss: 0.0895, Accuracy: 96.14%
# Epoch 225/500, Loss: 0.0909, Accuracy: 97.30%
# Epoch 226/500, Loss: 0.0945, Accuracy: 96.91%
# Epoch 227/500, Loss: 0.0776, Accuracy: 96.91%
# Epoch 228/500, Loss: 0.0818, Accuracy: 97.68%
# Epoch 229/500, Loss: 0.0658, Accuracy: 98.07%
# Epoch 230/500, Loss: 0.0739, Accuracy: 97.30%
# Epoch 231/500, Loss: 0.0834, Accuracy: 97.68%
# Epoch 232/500, Loss: 0.1030, Accuracy: 95.37%
# Epoch 233/500, Loss: 0.0733, Accuracy: 96.91%
# Epoch 234/500, Loss: 0.1015, Accuracy: 97.30%
# Epoch 235/500, Loss: 0.0823, Accuracy: 98.46%
# Epoch 236/500, Loss: 0.1216, Accuracy: 94.98%
# Epoch 237/500, Loss: 0.0851, Accuracy: 97.68%
# Epoch 238/500, Loss: 0.0898, Accuracy: 96.14%
# Epoch 239/500, Loss: 0.0974, Accuracy: 96.53%
# Epoch 240/500, Loss: 0.1023, Accuracy: 95.37%
# Epoch 241/500, Loss: 0.0864, Accuracy: 96.91%
# Epoch 242/500, Loss: 0.0628, Accuracy: 98.46%
# Epoch 243/500, Loss: 0.0819, Accuracy: 96.53%
# Epoch 244/500, Loss: 0.0823, Accuracy: 97.30%
# Epoch 245/500, Loss: 0.0847, Accuracy: 96.53%
# Epoch 246/500, Loss: 0.1076, Accuracy: 96.91%
# Epoch 247/500, Loss: 0.0846, Accuracy: 97.30%
# Epoch 248/500, Loss: 0.0945, Accuracy: 96.53%
# Epoch 249/500, Loss: 0.1317, Accuracy: 94.59%
# Epoch 250/500, Loss: 0.1180, Accuracy: 94.98%
# Epoch 251/500, Loss: 0.1033, Accuracy: 96.14%
# Epoch 252/500, Loss: 0.0880, Accuracy: 97.68%
# Epoch 253/500, Loss: 0.0791, Accuracy: 95.75%
# Epoch 254/500, Loss: 0.0729, Accuracy: 96.91%
# Epoch 255/500, Loss: 0.0737, Accuracy: 98.07%
# Epoch 256/500, Loss: 0.0861, Accuracy: 96.91%
# Epoch 257/500, Loss: 0.1359, Accuracy: 95.75%
# Epoch 258/500, Loss: 0.0729, Accuracy: 98.07%
# Epoch 259/500, Loss: 0.1322, Accuracy: 94.21%
# Epoch 260/500, Loss: 0.1237, Accuracy: 94.21%
# Epoch 261/500, Loss: 0.1059, Accuracy: 95.37%
# Epoch 262/500, Loss: 0.0945, Accuracy: 97.30%
# Epoch 263/500, Loss: 0.0892, Accuracy: 96.91%
# Epoch 264/500, Loss: 0.0915, Accuracy: 95.75%
# Epoch 265/500, Loss: 0.0898, Accuracy: 97.30%
# Epoch 266/500, Loss: 0.0946, Accuracy: 97.30%
# Epoch 267/500, Loss: 0.1025, Accuracy: 95.37%
# Epoch 268/500, Loss: 0.0799, Accuracy: 97.30%
# Epoch 269/500, Loss: 0.0689, Accuracy: 98.46%
# Epoch 270/500, Loss: 0.0671, Accuracy: 98.07%
# Epoch 271/500, Loss: 0.0883, Accuracy: 96.91%
# Epoch 272/500, Loss: 0.0665, Accuracy: 98.46%
# Epoch 273/500, Loss: 0.0881, Accuracy: 97.30%
# Epoch 274/500, Loss: 0.0812, Accuracy: 97.68%
# Epoch 275/500, Loss: 0.0984, Accuracy: 96.14%
# Epoch 276/500, Loss: 0.1016, Accuracy: 96.14%
# Epoch 277/500, Loss: 0.0605, Accuracy: 99.23%
# Epoch 278/500, Loss: 0.0898, Accuracy: 96.14%
# Epoch 279/500, Loss: 0.0872, Accuracy: 96.14%
# Epoch 280/500, Loss: 0.1105, Accuracy: 96.14%
# Epoch 281/500, Loss: 0.1237, Accuracy: 94.21%
# Epoch 282/500, Loss: 0.0836, Accuracy: 96.53%
# Epoch 283/500, Loss: 0.1177, Accuracy: 96.14%
# Epoch 284/500, Loss: 0.1061, Accuracy: 96.53%
# Epoch 285/500, Loss: 0.0756, Accuracy: 97.30%
# Epoch 286/500, Loss: 0.0933, Accuracy: 96.53%
# Epoch 287/500, Loss: 0.0821, Accuracy: 97.30%
# Epoch 288/500, Loss: 0.0890, Accuracy: 97.68%
# Epoch 289/500, Loss: 0.1058, Accuracy: 95.37%
# Epoch 290/500, Loss: 0.0716, Accuracy: 98.07%
# Epoch 291/500, Loss: 0.0869, Accuracy: 97.68%
# Epoch 292/500, Loss: 0.0911, Accuracy: 97.68%
# Epoch 293/500, Loss: 0.1095, Accuracy: 96.14%
# Epoch 294/500, Loss: 0.0469, Accuracy: 99.23%
# Epoch 295/500, Loss: 0.0664, Accuracy: 97.68%
# Epoch 296/500, Loss: 0.0804, Accuracy: 97.30%
# Epoch 297/500, Loss: 0.0998, Accuracy: 94.98%
# Epoch 298/500, Loss: 0.0839, Accuracy: 96.91%
# Epoch 299/500, Loss: 0.0810, Accuracy: 96.91%
# Epoch 300/500, Loss: 0.0774, Accuracy: 96.91%
# Epoch 301/500, Loss: 0.0945, Accuracy: 96.14%
# Epoch 302/500, Loss: 0.0552, Accuracy: 97.68%
# Epoch 303/500, Loss: 0.0543, Accuracy: 99.23%
# Epoch 304/500, Loss: 0.0663, Accuracy: 97.68%
# Epoch 305/500, Loss: 0.0637, Accuracy: 97.68%
# Epoch 306/500, Loss: 0.0533, Accuracy: 98.07%
# Epoch 307/500, Loss: 0.0730, Accuracy: 97.68%
# Epoch 308/500, Loss: 0.0557, Accuracy: 98.07%
# Epoch 309/500, Loss: 0.1050, Accuracy: 94.98%
# Epoch 310/500, Loss: 0.0833, Accuracy: 96.14%
# Epoch 311/500, Loss: 0.0677, Accuracy: 97.68%
# Epoch 312/500, Loss: 0.1025, Accuracy: 96.91%
# Epoch 313/500, Loss: 0.0764, Accuracy: 97.68%
# Epoch 314/500, Loss: 0.1108, Accuracy: 96.53%
# Epoch 315/500, Loss: 0.0573, Accuracy: 98.46%
# Epoch 316/500, Loss: 0.0677, Accuracy: 98.07%
# Epoch 317/500, Loss: 0.0824, Accuracy: 96.14%
# Epoch 318/500, Loss: 0.0766, Accuracy: 97.68%
# Epoch 319/500, Loss: 0.0802, Accuracy: 96.91%
# Epoch 320/500, Loss: 0.0496, Accuracy: 98.84%
# Epoch 321/500, Loss: 0.0463, Accuracy: 98.84%
# Epoch 322/500, Loss: 0.0551, Accuracy: 98.46%
# Epoch 323/500, Loss: 0.0685, Accuracy: 97.30%
# Epoch 324/500, Loss: 0.0465, Accuracy: 98.84%
# Epoch 325/500, Loss: 0.0732, Accuracy: 97.30%
# Epoch 326/500, Loss: 0.0779, Accuracy: 96.91%
# Epoch 327/500, Loss: 0.0702, Accuracy: 98.07%
# Epoch 328/500, Loss: 0.0729, Accuracy: 96.91%
# Epoch 329/500, Loss: 0.0502, Accuracy: 98.84%
# Epoch 330/500, Loss: 0.0611, Accuracy: 98.07%
# Epoch 331/500, Loss: 0.0773, Accuracy: 96.91%
# Epoch 332/500, Loss: 0.0410, Accuracy: 99.23%
# Epoch 333/500, Loss: 0.0706, Accuracy: 97.30%
# Epoch 334/500, Loss: 0.0747, Accuracy: 98.07%
# Epoch 335/500, Loss: 0.0878, Accuracy: 96.14%
# Epoch 336/500, Loss: 0.0650, Accuracy: 97.30%
# Epoch 337/500, Loss: 0.0895, Accuracy: 96.91%
# Epoch 338/500, Loss: 0.0567, Accuracy: 98.07%
# Epoch 339/500, Loss: 0.0648, Accuracy: 97.68%
# Epoch 340/500, Loss: 0.0530, Accuracy: 98.07%
# Epoch 341/500, Loss: 0.0461, Accuracy: 98.84%
# Epoch 342/500, Loss: 0.0434, Accuracy: 98.84%
# Epoch 343/500, Loss: 0.0638, Accuracy: 98.07%
# Epoch 344/500, Loss: 0.0673, Accuracy: 97.68%
# Epoch 345/500, Loss: 0.0813, Accuracy: 96.91%
# Epoch 346/500, Loss: 0.0587, Accuracy: 98.46%
# Epoch 347/500, Loss: 0.0588, Accuracy: 98.07%
# Epoch 348/500, Loss: 0.0798, Accuracy: 98.07%
# Epoch 349/500, Loss: 0.0872, Accuracy: 96.91%
# Epoch 350/500, Loss: 0.1120, Accuracy: 94.98%
# Epoch 351/500, Loss: 0.0919, Accuracy: 96.91%
# Epoch 352/500, Loss: 0.0781, Accuracy: 97.30%
# Epoch 353/500, Loss: 0.0683, Accuracy: 96.91%
# Epoch 354/500, Loss: 0.1055, Accuracy: 96.14%
# Epoch 355/500, Loss: 0.0566, Accuracy: 97.68%
# Epoch 356/500, Loss: 0.0870, Accuracy: 96.91%
# Epoch 357/500, Loss: 0.0724, Accuracy: 97.68%
# Epoch 358/500, Loss: 0.0951, Accuracy: 96.53%
# Epoch 359/500, Loss: 0.0858, Accuracy: 96.53%
# Epoch 360/500, Loss: 0.0662, Accuracy: 98.07%
# Epoch 361/500, Loss: 0.0755, Accuracy: 96.53%
# Epoch 362/500, Loss: 0.0644, Accuracy: 98.84%
# Epoch 363/500, Loss: 0.0548, Accuracy: 98.46%
# Epoch 364/500, Loss: 0.0484, Accuracy: 98.07%
# Epoch 365/500, Loss: 0.0694, Accuracy: 96.14%
# Epoch 366/500, Loss: 0.0470, Accuracy: 98.84%
# Epoch 367/500, Loss: 0.0797, Accuracy: 96.53%
# Epoch 368/500, Loss: 0.0647, Accuracy: 97.30%
# Epoch 369/500, Loss: 0.0706, Accuracy: 97.68%
# Epoch 370/500, Loss: 0.0760, Accuracy: 97.30%
# Epoch 371/500, Loss: 0.0657, Accuracy: 97.30%
# Epoch 372/500, Loss: 0.0500, Accuracy: 98.46%
# Epoch 373/500, Loss: 0.0794, Accuracy: 96.91%
# Epoch 374/500, Loss: 0.0506, Accuracy: 98.46%
# Epoch 375/500, Loss: 0.0489, Accuracy: 98.84%
# Epoch 376/500, Loss: 0.0660, Accuracy: 98.07%
# Epoch 377/500, Loss: 0.0714, Accuracy: 97.68%
# Epoch 378/500, Loss: 0.0776, Accuracy: 96.53%
# Epoch 379/500, Loss: 0.0765, Accuracy: 97.68%
# Epoch 380/500, Loss: 0.0722, Accuracy: 98.07%
# Epoch 381/500, Loss: 0.1164, Accuracy: 95.37%
# Epoch 382/500, Loss: 0.0730, Accuracy: 97.30%
# Epoch 383/500, Loss: 0.0745, Accuracy: 97.30%
# Epoch 384/500, Loss: 0.0914, Accuracy: 95.75%
# Epoch 385/500, Loss: 0.0933, Accuracy: 98.07%
# Epoch 386/500, Loss: 0.0719, Accuracy: 97.68%
# Epoch 387/500, Loss: 0.0710, Accuracy: 97.68%
# Epoch 388/500, Loss: 0.0444, Accuracy: 98.46%
# Epoch 389/500, Loss: 0.0674, Accuracy: 98.07%
# Epoch 390/500, Loss: 0.0851, Accuracy: 96.14%
# Epoch 391/500, Loss: 0.0929, Accuracy: 97.30%
# Epoch 392/500, Loss: 0.0911, Accuracy: 96.14%
# Epoch 393/500, Loss: 0.0850, Accuracy: 97.30%
# Epoch 394/500, Loss: 0.0709, Accuracy: 98.07%
# Epoch 395/500, Loss: 0.0880, Accuracy: 98.07%
# Epoch 396/500, Loss: 0.0799, Accuracy: 96.91%
# Epoch 397/500, Loss: 0.0748, Accuracy: 96.91%
# Epoch 398/500, Loss: 0.0616, Accuracy: 98.07%
# Epoch 399/500, Loss: 0.0491, Accuracy: 98.84%
# Epoch 400/500, Loss: 0.0846, Accuracy: 96.53%
# Epoch 401/500, Loss: 0.0700, Accuracy: 96.91%
# Epoch 402/500, Loss: 0.1006, Accuracy: 96.53%
# Epoch 403/500, Loss: 0.0488, Accuracy: 99.23%
# Epoch 404/500, Loss: 0.0564, Accuracy: 97.68%
# Epoch 405/500, Loss: 0.0624, Accuracy: 98.07%
# Epoch 406/500, Loss: 0.0466, Accuracy: 99.61%
# Epoch 407/500, Loss: 0.0784, Accuracy: 98.07%
# Epoch 408/500, Loss: 0.0738, Accuracy: 97.30%
# Epoch 409/500, Loss: 0.0577, Accuracy: 98.07%
# Epoch 410/500, Loss: 0.0653, Accuracy: 97.68%
# Epoch 411/500, Loss: 0.0558, Accuracy: 98.07%
# Epoch 412/500, Loss: 0.0425, Accuracy: 98.84%
# Epoch 413/500, Loss: 0.0635, Accuracy: 98.46%
# Epoch 414/500, Loss: 0.0674, Accuracy: 97.30%
# Epoch 415/500, Loss: 0.0488, Accuracy: 98.07%
# Epoch 416/500, Loss: 0.0787, Accuracy: 96.53%
# Epoch 417/500, Loss: 0.0830, Accuracy: 96.14%
# Epoch 418/500, Loss: 0.0541, Accuracy: 98.46%
# Epoch 419/500, Loss: 0.0831, Accuracy: 96.14%
# Epoch 420/500, Loss: 0.0552, Accuracy: 97.68%
# Epoch 421/500, Loss: 0.0613, Accuracy: 98.46%
# Epoch 422/500, Loss: 0.0663, Accuracy: 96.91%
# Epoch 423/500, Loss: 0.0597, Accuracy: 98.07%
# Epoch 424/500, Loss: 0.0655, Accuracy: 97.30%
# Epoch 425/500, Loss: 0.0788, Accuracy: 96.91%
# Epoch 426/500, Loss: 0.0581, Accuracy: 98.46%
# Epoch 427/500, Loss: 0.0728, Accuracy: 97.68%
# Epoch 428/500, Loss: 0.0442, Accuracy: 99.23%
# Epoch 429/500, Loss: 0.0782, Accuracy: 98.07%
# Epoch 430/500, Loss: 0.1009, Accuracy: 96.14%
# Epoch 431/500, Loss: 0.0671, Accuracy: 97.68%
# Epoch 432/500, Loss: 0.0770, Accuracy: 97.30%
# Epoch 433/500, Loss: 0.0860, Accuracy: 97.68%
# Epoch 434/500, Loss: 0.1001, Accuracy: 96.14%
# Epoch 435/500, Loss: 0.0543, Accuracy: 98.84%
# Epoch 436/500, Loss: 0.0564, Accuracy: 97.68%
# Epoch 437/500, Loss: 0.0351, Accuracy: 99.23%
# Epoch 438/500, Loss: 0.0499, Accuracy: 98.07%
# Epoch 439/500, Loss: 0.0709, Accuracy: 97.30%
# Epoch 440/500, Loss: 0.0514, Accuracy: 98.46%
# Epoch 441/500, Loss: 0.0470, Accuracy: 98.46%
# Epoch 442/500, Loss: 0.0546, Accuracy: 98.07%
# Epoch 443/500, Loss: 0.0602, Accuracy: 97.30%
# Epoch 444/500, Loss: 0.0460, Accuracy: 98.07%
# Epoch 445/500, Loss: 0.0774, Accuracy: 96.91%
# Epoch 446/500, Loss: 0.0635, Accuracy: 97.30%
# Epoch 447/500, Loss: 0.0603, Accuracy: 98.07%
# Epoch 448/500, Loss: 0.0545, Accuracy: 98.07%
# Epoch 449/500, Loss: 0.1015, Accuracy: 95.37%
# Epoch 450/500, Loss: 0.0586, Accuracy: 98.07%
# Epoch 451/500, Loss: 0.0474, Accuracy: 98.84%
# Epoch 452/500, Loss: 0.0583, Accuracy: 98.84%
# Epoch 453/500, Loss: 0.0736, Accuracy: 97.30%
# Epoch 454/500, Loss: 0.0624, Accuracy: 98.46%
# Epoch 455/500, Loss: 0.0760, Accuracy: 97.30%
# Epoch 456/500, Loss: 0.0651, Accuracy: 99.23%
# Epoch 457/500, Loss: 0.0642, Accuracy: 98.84%
# Epoch 458/500, Loss: 0.0751, Accuracy: 96.14%
# Epoch 459/500, Loss: 0.0605, Accuracy: 97.68%
# Epoch 460/500, Loss: 0.0449, Accuracy: 98.84%
# Epoch 461/500, Loss: 0.0580, Accuracy: 98.46%
# Epoch 462/500, Loss: 0.0741, Accuracy: 96.91%
# Epoch 463/500, Loss: 0.0350, Accuracy: 99.61%
# Epoch 464/500, Loss: 0.0726, Accuracy: 97.30%
# Epoch 465/500, Loss: 0.0675, Accuracy: 97.68%
# Epoch 466/500, Loss: 0.0887, Accuracy: 97.30%
# Epoch 467/500, Loss: 0.0403, Accuracy: 99.61%
# Epoch 468/500, Loss: 0.0529, Accuracy: 98.07%
# Epoch 469/500, Loss: 0.0695, Accuracy: 98.46%
# Epoch 470/500, Loss: 0.0812, Accuracy: 96.14%
# Epoch 471/500, Loss: 0.0965, Accuracy: 96.53%
# Epoch 472/500, Loss: 0.0807, Accuracy: 96.91%
# Epoch 473/500, Loss: 0.0585, Accuracy: 97.68%
# Epoch 474/500, Loss: 0.0635, Accuracy: 98.07%
# Epoch 475/500, Loss: 0.0556, Accuracy: 97.68%
# Epoch 476/500, Loss: 0.0618, Accuracy: 98.46%
# Epoch 477/500, Loss: 0.0542, Accuracy: 97.68%
# Epoch 478/500, Loss: 0.0457, Accuracy: 98.07%
# Epoch 479/500, Loss: 0.0763, Accuracy: 97.30%
# Epoch 480/500, Loss: 0.0337, Accuracy: 99.23%
# Epoch 481/500, Loss: 0.0571, Accuracy: 98.07%
# Epoch 482/500, Loss: 0.0480, Accuracy: 98.07%
# Epoch 483/500, Loss: 0.0643, Accuracy: 98.07%
# Epoch 484/500, Loss: 0.0517, Accuracy: 98.07%
# Epoch 485/500, Loss: 0.0618, Accuracy: 98.07%
# Epoch 486/500, Loss: 0.0365, Accuracy: 99.61%
# Epoch 487/500, Loss: 0.0475, Accuracy: 98.46%
# Epoch 488/500, Loss: 0.0980, Accuracy: 96.91%
# Epoch 489/500, Loss: 0.0496, Accuracy: 97.68%
# Epoch 490/500, Loss: 0.0346, Accuracy: 98.46%
# Epoch 491/500, Loss: 0.0561, Accuracy: 98.07%
# Epoch 492/500, Loss: 0.0394, Accuracy: 99.61%
# Epoch 493/500, Loss: 0.0571, Accuracy: 97.68%
# Epoch 494/500, Loss: 0.0464, Accuracy: 99.23%
# Epoch 495/500, Loss: 0.0414, Accuracy: 98.46%
# Epoch 496/500, Loss: 0.0431, Accuracy: 99.23%
# Epoch 497/500, Loss: 0.0591, Accuracy: 98.46%
# Epoch 498/500, Loss: 0.0575, Accuracy: 98.07%
# Epoch 499/500, Loss: 0.0611, Accuracy: 98.46%
# Epoch 500/500, Loss: 0.0567, Accuracy: 98.46%
# Average Loss: 0.0567249787394245
# Highest Train Accuracy: 0.9961389961389961

# %%
# =============================================================================
# 模型评估: 计算测试准确率 + 绘制混淆矩阵 (二分类)
# =============================================================================

# 定义两个运动想象类别名称
#   0: Left   -- 左手运动想象
#   1: Right  -- 右手运动想象
classes_list = ['Left', 'Right']

# 实例化评估器, 传入训练好的模型
eval_model = EvalModel(trained_eegnet_model)

# 第一步: 计算测试集准确率
test_accuracy = eval_model.test_model(test_dataset)

# 第二步: 绘制归一化混淆矩阵
eval_model.plot_confusion_matrix(test_dataset, classes_list)
# Out:
# /------------------------------/
# Test Accuracy: 93.10%
# /------------------------------/
